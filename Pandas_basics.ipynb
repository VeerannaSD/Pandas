# %%
import pandas as pd

import numpy as np

# %%
data=np.random.random(size=(5,3))
data
# Out:
# array([[0.5854352 , 0.78409178, 0.86964925],
#        [0.62359719, 0.12578507, 0.96073108],
#        [0.59417212, 0.27595303, 0.06536325],
#        [0.79700344, 0.97436874, 0.57782597],
#        [0.27453018, 0.62364368, 0.18252827]])

# %%
#Dataframe with numpy array
df=pd.DataFrame(data,columns=['A','B','C'])
df
# Out:
#           A         B         C
# 0  0.585435  0.784092  0.869649
# 1  0.623597  0.125785  0.960731
# 2  0.594172  0.275953  0.065363
# 3  0.797003  0.974369  0.577826
# 4  0.274530  0.623644  0.182528

# %%
#Dataframe using discionary
df=pd.DataFrame(data={'A':[1,2,3],'B':['Veer','Veena','Vishal']})
df
# Out:
#    A       B
# 0  1    Veer
# 1  2   Veena
# 2  3  Vishal

# %%
dtype=[('A',np.int64),('B',(str,20))]
data=np.array([(1,'Ashwini'),(2,'Deepa'),(3,'Anju'),(4,'Ramu')])
df=pd.DataFrame(data)
df
# Out:
#    0        1
# 0  1  Ashwini
# 1  2    Deepa
# 2  3     Anju
# 3  4     Ramu

# %% [markdown]
# Saving and Serializing a dataframe

# %%
df=pd.DataFrame(np.random.random(size=(50,4)),columns=['A','B','C','D'])
df.head()
# Out:
#           A         B         C         D
# 0  0.466286  0.709685  0.617497  0.158222
# 1  0.410661  0.229063  0.211226  0.110289
# 2  0.094401  0.801238  0.300439  0.959903
# 3  0.528662  0.139395  0.113223  0.030893
# 4  0.484305  0.853135  0.880597  0.886626

# %%
#Saving data in csv format
df.to_csv("save.csv",index=False,float_format="%0.4f")

# %%
#Saving data in pkl format
df.to_pickle("save.pkl")

# %%
#Download data from https://www.kaggle.com/datasets/nasa/astronaut-yearbook
df=pd.read_csv('astronauts.csv')
df.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
# %ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 0C14-D468
#
#  Directory of C:\Users\Admin\Pandas
#
# 18-09-2022  12:36    <DIR>          .
# 18-09-2022  12:36    <DIR>          ..
# 18-09-2022  12:32    <DIR>          .ipynb_checkpoints
# 18-09-2022  12:32            81,593 astronauts.csv
# 18-09-2022  12:36            19,046 Pandas_basics.ipynb
# 18-09-2022  12:24             1,459 save.csv
# 18-09-2022  12:33             2,373 save.pkl
#                4 File(s)        104,471 bytes
#                3 Dir(s)  30,891,565,056 bytes free

# %%
df.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
df.tail()
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 352   Indianapolis, IN   Male
# 353        Chicago, IL   Male
# 354        Jackson, MI   Male
# 355  San Francisco, CA   Male
# 356    Jersey City, NJ   Male
#
#                                             Alma Mater  \
# 352              Purdue University; Indiana University
# 353  MIT; University of Texas-Austin; George Washin...
# 354        US Military Academy; University of Michigan
# 355                    Georgia Institute of Technology
# 356  US Naval Academy; Florida Institute of Technology
#
# ...

# %%
df.sample(3)#Randomly picking values
# Out:
#                      Name    Year  Group    Status Birth Date     Birth Place  \
# 312  John L. Swigert Jr.   1966.0    5.0  Deceased  8/30/1931      Denver, CO
# 270    Garrett E. Reisman  1998.0   17.0   Retired  2/10/1968  Morristown, NJ
# 161      David C. Hilmers  1980.0    9.0   Retired  1/28/1950     Clinton, IA
#
#     Gender                                         Alma Mater  \
# 312   Male  University of Colorado; Rensselaer Polytechnic...
# 270   Male  University of Pennsylvania; California Institu...
# 161   Male   Cornell University; US Naval Postgraduate School
#
#         Undergraduate Major                              Graduate Major  \
# 312  Mechanical Engineering  Aerospace Science; Business Administration
# 270               Economics                     Mechanical  Engineering
# 161             Mathematics                      Electrical Engineering
#
#     Military Rank            Military Branch  Space Flights  \
# ...

# %%
#details of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 357 non-null    object
#  1   Year                 330 non-null    float64
#  2   Group                330 non-null    float64
#  3   Status               357 non-null    object
#  4   Birth Date           357 non-null    object
#  5   Birth Place          357 non-null    object
#  6   Gender               357 non-null    object
#  7   Alma Mater           356 non-null    object
#  8   Undergraduate Major  335 non-null    object
#  9   Graduate Major       298 non-null    object
#  10  Military Rank        207 non-null    object
#  11  Military Branch      211 non-null    object
#  12  Space Flights        357 non-null    int64
#  13  Space Flight (hr)    357 non-null    int64
#  14  Space Walks          357 non-null    int64
# ...

# %%
df.describe()
# Out:
#               Year       Group  Space Flights  Space Flight (hr)  Space Walks  \
# count   330.000000  330.000000     357.000000         357.000000   357.000000
# mean   1985.106061   11.409091       2.364146        1249.266106     1.246499
# std      13.216147    5.149962       1.428700        1896.759857     2.056989
# min    1959.000000    1.000000       0.000000           0.000000     0.000000
# 25%    1978.000000    8.000000       1.000000         289.000000     0.000000
# 50%    1987.000000   12.000000       2.000000         590.000000     0.000000
# 75%    1996.000000   16.000000       3.000000        1045.000000     2.000000
# max    2009.000000   20.000000       7.000000       12818.000000    10.000000
#
#        Space Walks (hr)
# count        357.000000
# mean           7.707283
# std           13.367973
# min            0.000000
# 25%            0.000000
# 50%            0.000000
# 75%           12.000000
# max           67.000000

# %%
#shape and size of the data
df.shape
# Out:
# (357, 19)

# %%
df.corr()
# Out:
#                        Year     Group  Space Flights  Space Flight (hr)  \
# Year               1.000000  0.980934       0.036420           0.331386
# Group              0.980934  1.000000      -0.011386           0.325683
# Space Flights      0.036420 -0.011386       1.000000           0.325233
# Space Flight (hr)  0.331386  0.325683       0.325233           1.000000
# Space Walks        0.210073  0.217891       0.257073           0.472796
# Space Walks (hr)   0.253502  0.261384       0.258642           0.454408
#
#                    Space Walks  Space Walks (hr)
# Year                  0.210073          0.253502
# Group                 0.217891          0.261384
# Space Flights         0.257073          0.258642
# Space Flight (hr)     0.472796          0.454408
# Space Walks           1.000000          0.985755
# Space Walks (hr)      0.985755          1.000000

# %%
#Number of times data occured in dataset
df.Year.value_counts()
# Out:
# 1996.0    35
# 1978.0    35
# 1998.0    25
# 1990.0    23
# 1966.0    19
# 1995.0    19
# 1992.0    19
# 1980.0    19
# 1984.0    18
# 2000.0    17
# 1987.0    15
# 1963.0    14
# 1985.0    13
# 2004.0    11
# 1967.0    11
# 2009.0     9
# 1962.0     8
# 1959.0     7
# 1969.0     7
# 1965.0     6
# Name: Year, dtype: int64

# %%
#max max in each coulmn
df.max()
# Out:
# Name                 Yvonne D. Cagle
# Year                          2009.0
# Group                           20.0
# Status                       Retired
# Birth Date                  9/9/1952
# Birth Place              Yonkers, NY
# Gender                          Male
# Space Flights                      7
# Space Flight (hr)              12818
# Space Walks                       10
# Space Walks (hr)                67.0
# dtype: object
